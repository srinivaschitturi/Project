# %% [markdown]
# Initialize the variables and libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

###### Declaring Variables #######

x0=np.zeros([100,1])
x1=np.zeros([100,1])
x2=np.full([100,1],1)
y=np.zeros([100,1])
yact=np.zeros(100)
ypred=np.zeros(100)
cost=0
gradient=0
iteration=0
slope=np.tan(np.arcsin(np.random.random()))
weights=np.array([1,-slope,0])
weightsPred=np.array([1,1,0])
weightsPredPrev=2*weightsPred

# %% [markdown]
# Step 1: Data Creation
#
# For the purpose of data generation the following method has been used.
#   1. A circle is used as a boundary of data points and points generated uniformly across the area of circle.
#   2. For uniform generation of data the radial distance from center is square root of a random number * radius.
#   3. Square root is essential for uniform distribution else majority of points are distributed around centre.
#   4. $$ r=\sqrt{random number}*max radius$$
#   5. $$\theta=(2*random number-1)*\pi$$
#   6. Coordinates of points stored in x array. Plots made to explain the creation of points and encapsulating circle.

# %%
###### Generating uniformly distributed points in a circle ######

for i in range(100):
    r=np.sqrt(np.random.random())*1 ### Sqrt is used for uniform distribution
    theta=(np.random.random()*2-1)*np.pi
    x1[i]=r*np.cos(theta)
    y[i]=r*np.sin(theta)
    plt.scatter(x1[i],y[i])
    circle1 = plt.Circle((0, 0), 1, color='b', fill=False)
    fig = plt.gcf()
    ax = fig.gca()
    ax.add_artist(circle1)
plt.plot([-1,1],[slope*(-1),slope*(1)])
x=np.column_stack((y,x1,x2))

# %% [markdown]
# Classification of data is done into two different labels. If y>x.weights, yact values are assigned TRUE or 1. Else they are assigned FALSE or 0. Similarly ypred values are assigned using the sigmoid function.

# %%
###### Classifying Data ######

for i in range(100):
    if (np.dot(x[i],weights))>0:
        yact[i]=1
    else:
        yact[i]=0
    ypred[i]=1/(1+np.power(np.e,-np.dot(x[i],weightsPred)))

# %% [markdown]
# Data is now split into Train and Test to prevent underfitting or overfitting.

# %%
###### Split data into Test Train ######
j=0.7
yactTrain=yact[0:int(len(x)*j)]
ypredTrain=ypred[0:int(len(x)*j)]
xtrain=x[0:int(len(x)*j)]
yactTest=yact[int(len(x)*j)+1:len(x)]
ypredTest=ypred[int(len(x)*j)+1:len(x)]
xtest=x[int(len(x)*j)+1:len(x)]

# %% [markdown]
# Stochastic Gradient Descent is used to find the weights for training data. Learning rate is adjusted to 0.1 and convergence criterion is norm of difference of weights < 0.00001

# %%
###### Gradient Descent - Training data ######

while np.linalg.norm(weightsPred-weightsPredPrev)>0.00001:
    for i in range(70):        
        gradient=np.dot((yactTrain[i]-ypredTrain[i]),xtrain[i])
        weightsPredPrev=weightsPred
        weightsPred=weightsPred+gradient*1E-1
        ypredTrain[i]=1/(1+np.power(np.e,-np.dot(xtrain[i],weightsPred)))
    iteration=iteration+1
print(weightsPred)
# Out:
# [ 17.07878057 -13.94560359   0.37229586]

# %% [markdown]
# Testing of data is done to check the accuracy of weights.

# %%
###### Testing Data ######

for i in range(int((1-j)*int(len(x)))-1):
    ypredTest[i]=1/(1+np.power(np.e,-np.dot(xtest[i],weightsPred)))
    cost-=(yactTest[i]*np.log10(ypredTest[i])+(1-yactTest[i])*np.log10(1-ypredTest[i]))
    if ypredTest[i]<0.5:
        ypredTest[i]=0
    else:
        ypredTest[i]=1
print(slope)
print(cost)
print(np.mean(ypredTest==yactTest))
print(-weightsPred[1]/weightsPred[0])
plt.plot([-1,1],[-weightsPred[1]*(-1)/weightsPred[0],-weightsPred[1]*(1)/weightsPred[0]])
plt.show()
# Out:
# 0.750165588642
# 0.501085204076
# 1.0
# 0.81654562742

# %% [markdown]
# Accuracy of 1 shows that all the testing data sample were classified correctly.
#
# While the initial slope required to classify the data was 0.75, gradient descent obtained a slope of 0.816 as the boundary. This can be further improved by making the convergence criterion stricter.
#
# Cost value for training sample is found to be 0.50108
#
# As the plot and results show a very good accuracy has been achieved.

# %% [markdown]
# Checking on user input data. User inputs 2 variables(x and y coordinates). Program classifies it accordingly based on its orientation with respect to the line.

# %%
input1=float(input("Enter x coordinate"))
input2=float(input("Enter y coordinate"))
if 1/(1+np.power(np.e,-np.dot([input2,input1,1],weightsPred)))>=0.5:
    print("TRUE")
else:
    print("FALSE")
# Out:
# Enter x coordinate-0.5
# Enter y coordinate0.5
# TRUE

# %%
input1=float(input("Enter x coordinate"))
input2=float(input("Enter y coordinate"))
if 1/(1+np.power(np.e,-np.dot([input2,input1,1],weightsPred)))>=0.5:
    print("TRUE")
else:
    print("FALSE")
# Out:
# Enter x coordinate0.5
# Enter y coordinate-0.75
# FALSE

# %% [markdown]
# As visible from the above two test cases, the program classifies user input data accurately.

# %%
slope=np.tan(np.arcsin(np.random.random()))
weights=np.array([1,-slope,0])
weightsPred=np.array([1,1,0])
weightsPredPrev=2*weightsPred

###### Generating uniformly distributed points in a circle ######

for i in range(100):
    r=np.sqrt(np.random.random())*1 ### Sqrt is used for uniform distribution
    theta=(np.random.random()*2-1)*np.pi
    x1[i]=r*np.cos(theta)
    y[i]=r*np.sin(theta)
    plt.scatter(x1[i],y[i])
    circle1 = plt.Circle((0, 0), 1, color='b', fill=False)
    fig = plt.gcf()
    ax = fig.gca()
    ax.add_artist(circle1)
plt.plot([-1,1],[slope*(-1),slope*(1)])
x=np.column_stack((y,x1,x2))

###### Classifying Data ######

for i in range(100):
    if (np.dot(x[i],weights))>0:
        yact[i]=1
    else:
        yact[i]=0
    ypred[i]=1/(1+np.power(np.e,-np.dot(x[i],weightsPred)))
    
###### Split data into Test Train ######
j=0.7
yactTrain=yact[0:int(len(x)*j)]
ypredTrain=ypred[0:int(len(x)*j)]
xtrain=x[0:int(len(x)*j)]
yactTest=yact[int(len(x)*j)+1:len(x)]
ypredTest=ypred[int(len(x)*j)+1:len(x)]
xtest=x[int(len(x)*j)+1:len(x)]
    
###### Gradient Descent - Training data ######

while np.linalg.norm(weightsPred-weightsPredPrev)>0.00001:
    for i in range(70):        
        gradient=np.dot((yactTrain[i]-ypredTrain[i]),xtrain[i])
        weightsPredPrev=weightsPred
        weightsPred=weightsPred+gradient*1E-1
        ypredTrain[i]=1/(1+np.power(np.e,-np.dot(xtrain[i],weightsPred)))
    iteration=iteration+1
print(weightsPred)
    
###### Testing Data ######

for i in range(int((1-j)*int(len(x)))-1):
    ypredTest[i]=1/(1+np.power(np.e,-np.dot(xtest[i],weightsPred)))
    cost-=(yactTest[i]*np.log10(ypredTest[i])+(1-yactTest[i])*np.log10(1-ypredTest[i]))
    if ypredTest[i]<0.5:
        ypredTest[i]=0
    else:
        ypredTest[i]=1
print(slope)
print(cost)
print(np.mean(ypredTest==yactTest))
print(-weightsPred[1]/weightsPred[0])
plt.plot([-1,1],[-weightsPred[1]*(-1)/weightsPred[0],-weightsPred[1]*(1)/weightsPred[0]])
plt.show()
# Out:
# [ 17.80612368   0.07660068  -0.07222716]
# 0.0450713079509
# 1.07542718785
# 1.0
# -0.00430192885053

# %% [markdown]
# Since the slope of classifying line is random, the program has been rerun to show different classifying boundaries being identified accurately with 100% testing data accuracy.

# %%
slope=np.tan(np.arcsin(np.random.random()))
weights=np.array([1,-slope,0])
weightsPred=np.array([1,1,0])
weightsPredPrev=2*weightsPred

###### Generating uniformly distributed points in a circle ######

for i in range(100):
    r=np.sqrt(np.random.random())*1 ### Sqrt is used for uniform distribution
    theta=(np.random.random()*2-1)*np.pi
    x1[i]=r*np.cos(theta)
    y[i]=r*np.sin(theta)
    circle1 = plt.Circle((0, 0), 1, color='b', fill=False)
    fig = plt.gcf()
    ax = fig.gca()
    ax.add_artist(circle1)
plt.plot([-1,1],[slope*(-1),slope*(1)])
x=np.column_stack((y,x1,x2))

###### Classifying Data ######

for i in range(100):
    if (np.dot(x[i],weights))>0:
        yact[i]=1
        plt.scatter(x1[i],y[i],c='g')
    else:
        yact[i]=0
        plt.scatter(x1[i],y[i],c='r')
    ypred[i]=1/(1+np.power(np.e,-np.dot(x[i],weightsPred)))
    
###### Split data into Test Train ######
j=0.7
yactTrain=yact[0:int(len(x)*j)]
ypredTrain=ypred[0:int(len(x)*j)]
xtrain=x[0:int(len(x)*j)]
yactTest=yact[int(len(x)*j)+1:len(x)]
ypredTest=ypred[int(len(x)*j)+1:len(x)]
xtest=x[int(len(x)*j)+1:len(x)]
    
###### Gradient Descent - Training data ######

while np.linalg.norm(weightsPred-weightsPredPrev)>0.00001:
    for i in range(70):        
        gradient=np.dot((yactTrain[i]-ypredTrain[i]),xtrain[i])
        weightsPredPrev=weightsPred
        weightsPred=weightsPred+gradient*1E-1
        ypredTrain[i]=1/(1+np.power(np.e,-np.dot(xtrain[i],weightsPred)))
    iteration=iteration+1
print(weightsPred)
    
###### Testing Data ######

for i in range(int((1-j)*int(len(x)))-1):
    ypredTest[i]=1/(1+np.power(np.e,-np.dot(xtest[i],weightsPred)))
    cost-=(yactTest[i]*np.log10(ypredTest[i])+(1-yactTest[i])*np.log10(1-ypredTest[i]))
    if ypredTest[i]<0.5:
        ypredTest[i]=0
    else:
        ypredTest[i]=1
print(slope)
print(cost)
print(np.mean(ypredTest==yactTest))
print(-weightsPred[1]/weightsPred[0])
plt.plot([-1,1],[-weightsPred[1]*(-1)/weightsPred[0],-weightsPred[1]*(1)/weightsPred[0]])
plt.show()
# Out:
# [ 10.02205447 -10.87476829   0.47658169]
# 0.990760494991
# 2.9146716528
# 1.0
# 1.08508373504

# %% [markdown]
# One more test case to exemplify the point. 100% accuracy achieved.

# %% [markdown]
# Initialize the variables and libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

###### Declaring Variables #######

x0=np.zeros([100,1])
x1=np.zeros([100,1])
x2=np.full([100,1],1)
y=np.zeros([100,1])
yact=np.zeros(100)
ypred=np.zeros(100)
cost=0
gradient=0
iteration=0
params=np.random.random(2)*1
weights=np.array([params[0],params[1],-1])
weightsPred=np.array([1,1,1])
weightsPredPrev=2*weightsPred

# %% [markdown]
# Data Creation
#
# For the purpose of data generation the following method has been used.
#   1. A circle is used as a boundary of data points and points generated uniformly across the area of circle. Radius = 2
#   2. For uniform generation of data the radial distance from center is square root of a random number * radius.
#   3. Square root is essential for uniform distribution else majority of points are distributed around centre.
#   4. $$ r=\sqrt{random number}*max radius$$
#   5. $$\theta=(2*random number-1)*\pi$$
#   6. Coordinates of points stored in x array.
#   7. Squares of point coordinates used as feature vectors to create an elliptic boundary.
#   8. Target ellipse and dataset plotted with randomly generated axes lengths.

# %%
###### Generating uniformly distributed points in a circle of radius 3 ######

for i in range(100):
    r=np.sqrt(np.random.random())*2 ### Sqrt is used for uniform distribution
    theta=(np.random.random()*2-1)*np.pi
    x1[i]=r*np.cos(theta)
    y[i]=r*np.sin(theta)
    plt.scatter(x1[i],y[i])
    ells = Ellipse(xy=[0,0], width=2/np.sqrt(params[1]), height=2/np.sqrt(params[0]), angle=0,fc='none',ec='b')
    fig = plt.gcf()
    ax = fig.gca()
    ax.add_artist(ells)
    ax.set_xlim(-3, 3)
    ax.set_ylim(-3, 3)
#plt.plot([-1,1],[slope*(-1),slope*(1)])
x=np.column_stack((np.square(y),np.square(x1),np.square(x2)))

# %% [markdown]
# Classification of data is done into two different labels. If y>x.weights, yact values are assigned TRUE or 1. Else they are assigned FALSE or 0. Similarly ypred values are assigned using the sigmoid function.

# %%
for i in range(100):
    if (np.dot(x[i],weights))>0:
        yact[i]=1
    else:
        yact[i]=0
    ypred[i]=1/(1+np.power(np.e,-np.dot(x[i],weightsPred)))

# %% [markdown]
# Data is now split into Train and Test to prevent underfitting or overfitting.

# %%
###### Split data into Test Train ######
j=0.7
yactTrain=yact[0:int(len(x)*j)]
ypredTrain=ypred[0:int(len(x)*j)]
xtrain=x[0:int(len(x)*j)]
yactTest=yact[int(len(x)*j)+1:len(x)]
ypredTest=ypred[int(len(x)*j)+1:len(x)]
xtest=x[int(len(x)*j)+1:len(x)]

# %% [markdown]
# Stochastic Gradient Descent is used to find the weights for training data. Learning rate is adjusted to 0.1 and convergence criterion is norm of difference of weights < 0.00001

# %%
###### Gradient Descent - Training data ######

while np.linalg.norm(weightsPred-weightsPredPrev)>0.00001:
    for i in range(70):        
        #cost-=(yact*np.log10(ypred)+(1-yact)*np.log10(1-ypred))
        gradient=np.dot((yactTrain[i]-ypredTrain[i]),xtrain[i])
        weightsPredPrev=weightsPred
        weightsPred=weightsPred+gradient*1E-2 
        #print(weightsPred)
        ypredTrain[i]=1/(1+np.power(np.e,-np.dot(xtrain[i],weightsPred)))
    #rmse=np.linalg.norm(cost)
    iteration=iteration+1
    #plt.scatter(iteration,rmse)
    #if j==0.7:
print(weightsPred)
# Out:
# [ 3.37486442  0.60075546 -8.09127708]

# %% [markdown]
# Testing of data is done to check the accuracy of weights.

# %%
###### Testing Data ######

for i in range(int((1-j)*int(len(x)))-1):
    ypredTest[i]=1/(1+np.power(np.e,-np.dot(xtest[i],weightsPred)))
    cost-=(yactTest[i]*np.log10(ypredTest[i])+(1-yactTest[i])*np.log10(1-ypredTest[i]))
    if ypredTest[i]<0.5:
        ypredTest[i]=0
    else:
        ypredTest[i]=1
print(cost)
print(np.mean(ypredTest==yactTest))
ells1 = Ellipse(xy=[0,0], width=2*np.sqrt(-weightsPred[2]/weightsPred[1]), height=2*np.sqrt(-weightsPred[2]/weightsPred[0]), angle=0,fc='none',ec='r')
ax.add_artist(ells1)
#plt.plot([-1,1],[-weightsPred[1]*(-1)/weightsPred[0],-weightsPred[1]*(1)/weightsPred[0]])
plt.show()
# Out:
# 0.847940917779
# 0.965517241379

# %% [markdown]
# An accuracy of 96.55% is achieved with only test case misclassified incorrectly.
#
# Checking on user input data. User inputs 2 variables(x and y coordinates). Program classifies it accordingly based on its orientation with respect to the line.

# %%
input1=float(input("Enter x coordinate"))
input2=float(input("Enter y coordinate"))
if 1/(1+np.power(np.e,-np.dot([input2,input1,1],weightsPred)))>=0.5:
    print("TRUE")
else:
    print("FALSE")
# Out:
# Enter x coordinate0
# Enter y coordinate-2
# FALSE

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

###### Declaring Variables #######

x0=np.zeros([100,1])
x1=np.zeros([100,1])
x2=np.full([100,1],1)
y=np.zeros([100,1])
yact=np.zeros(100)
ypred=np.zeros(100)
cost=0
gradient=0
iteration=0
params=np.random.random(2)*1
#params=np.array([2,1])
weights=np.array([params[0],params[1],-1])
weightsPred=np.array([1,1,1])
weightsPredPrev=2*weightsPred

###### Generating uniformly distributed points in a circle of radius 3 ######

for i in range(100):
    r=np.sqrt(np.random.random())*2 ### Sqrt is used for uniform distribution
    theta=(np.random.random()*2-1)*np.pi
    x1[i]=r*np.cos(theta)
    y[i]=r*np.sin(theta)
    ells = Ellipse(xy=[0,0], width=2/np.sqrt(params[1]), height=2/np.sqrt(params[0]), angle=0,fc='none',ec='b')
    fig = plt.gcf()
    ax = fig.gca()
    ax.add_artist(ells)
    ax.set_xlim(-3, 3)
    ax.set_ylim(-3, 3)
#plt.plot([-1,1],[slope*(-1),slope*(1)])
x=np.column_stack((np.square(y),np.square(x1),np.square(x2)))

###### Classifying Data ######

for i in range(100):
    if (np.dot(x[i],weights))>0:
        yact[i]=1
        plt.scatter(x1[i],y[i],c='g')
    else:
        yact[i]=0
        plt.scatter(x1[i],y[i],c='r')
    ypred[i]=1/(1+np.power(np.e,-np.dot(x[i],weightsPred)))
    
###### Split data into Test Train ######
j=0.7
yactTrain=yact[0:int(len(x)*j)]
ypredTrain=ypred[0:int(len(x)*j)]
xtrain=x[0:int(len(x)*j)]
yactTest=yact[int(len(x)*j)+1:len(x)]
ypredTest=ypred[int(len(x)*j)+1:len(x)]
xtest=x[int(len(x)*j)+1:len(x)]
    
###### Gradient Descent - Training data ######

while np.linalg.norm(weightsPred-weightsPredPrev)>0.00001:
    for i in range(70):        
        #cost-=(yact*np.log10(ypred)+(1-yact)*np.log10(1-ypred))
        gradient=np.dot((yactTrain[i]-ypredTrain[i]),xtrain[i])
        weightsPredPrev=weightsPred
        weightsPred=weightsPred+gradient*1E-2 
        #print(weightsPred)
        ypredTrain[i]=1/(1+np.power(np.e,-np.dot(xtrain[i],weightsPred)))
    #rmse=np.linalg.norm(cost)
    iteration=iteration+1
    #plt.scatter(iteration,rmse)
    #if j==0.7:
print(weightsPred)
    
###### Testing Data ######

for i in range(int((1-j)*int(len(x)))-1):
    ypredTest[i]=1/(1+np.power(np.e,-np.dot(xtest[i],weightsPred)))
    cost-=(yactTest[i]*np.log10(ypredTest[i])+(1-yactTest[i])*np.log10(1-ypredTest[i]))
    if ypredTest[i]<0.5:
        ypredTest[i]=0
    else:
        ypredTest[i]=1
print(cost)
print(np.mean(ypredTest==yactTest))
ells1 = Ellipse(xy=[0,0], width=2*np.sqrt(-weightsPred[2]/weightsPred[1]), height=2*np.sqrt(-weightsPred[2]/weightsPred[0]), angle=0,fc='none',ec='r')
ax.add_artist(ells1)
#plt.plot([-1,1],[-weightsPred[1]*(-1)/weightsPred[0],-weightsPred[1]*(1)/weightsPred[0]])
plt.show()

###### Testing user input data ######

input1=input("Enter x coordinate")
input2=input("Enter y coordinate")
if 1/(1+np.power(np.e,-np.dot([float(input2),float(input1),1],weightsPred)))>=0.5:
    print("TRUE")
else:
    print("FALSE")
# Out:
# [ 29.26483711  33.67567344 -49.15171908]
# nan
# 1.0
# C:\Users\srini\Anaconda3\lib\site-packages\ipykernel_launcher.py:78: RuntimeWarning: divide by zero encountered in log10
# C:\Users\srini\Anaconda3\lib\site-packages\ipykernel_launcher.py:78: RuntimeWarning: invalid value encountered in double_scalars
# Enter x coordinate1
# Enter y coordinate1
# TRUE

# %% [markdown]
# Complete program run.
#
# The axes values are obtained from weights as
# $$ a = \sqrt{-weights[2]/weights[1]} = 1.12$$
# $$ b = \sqrt{-weights[2]/weights[0]} = 1.18$$
#
# Cost value using cross entropy function is obtained as 1.9754
#
# 100% testing data accuracy was achieved and user input data was also found to be classified satisfactorily.

# %% [markdown]
# 2) Digit Classification problem
#
# Initializing Libraries and variables

# %%
import gzip
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

aTrain=np.zeros(1,dtype=int)
aTest=np.zeros(1,dtype=int)
countTrain=0;
countTest=0;
weightsPred=np.full(785,1)
weightsPredPrev=weightsPred*2
iteration=0       
cost=0

# %% [markdown]
# Using gzip.open command and using offsets mentioned in the website of MNIST data, data is imported into a numpy array as unsigned 8 bit integer.

# %%
with gzip.open('C:\\Users\\srini\\OneDrive\\Academics\\ML courses\\ID 5030\\Assignments\\Assignment 2\\Digits\\train-images-idx3-ubyte.gz', 'rb') as f:
            imgarrayTrain = np.frombuffer(f.read(),dtype=np.uint8, offset=16)

with gzip.open('C:\\Users\\srini\\OneDrive\\Academics\\ML courses\\ID 5030\\Assignments\\Assignment 2\\Digits\\train-labels-idx1-ubyte.gz', 'rb') as f:
            labelsTrain = np.frombuffer(f.read(),dtype=np.uint8, offset=8)
            
with gzip.open('C:\\Users\\srini\\OneDrive\\Academics\\ML courses\\ID 5030\\Assignments\\Assignment 2\\Digits\\t10k-images-idx3-ubyte.gz', 'rb') as f:
            imgarrayTest = np.frombuffer(f.read(),dtype=np.uint8, offset=16)

with gzip.open('C:\\Users\\srini\\OneDrive\\Academics\\ML courses\\ID 5030\\Assignments\\Assignment 2\\Digits\\t10k-labels-idx1-ubyte.gz', 'rb') as f:
            labelsTest = np.frombuffer(f.read(),dtype=np.uint8, offset=8)

# %% [markdown]
# Indexes of data containing only 1s and 0s is then collected in an array aTrain and aTest. This is later used to separate the label values of both test and train data in yactTrain and yactTest.

# %%
for k in range(len(labelsTrain)):
    if (labelsTrain[k]==1) | (labelsTrain[k]==0):
        countTrain=countTrain+1
        if countTrain==1:
            aTrain[0]=k
        else:
            aTrain=np.concatenate([aTrain,[int(k)]])

for k in range(len(labelsTest)):
    if (labelsTest[k]==1) | (labelsTest[k]==0):
        countTest=countTest+1
        if countTest==1:
            aTest[0]=k
        else:
            aTest=np.concatenate([aTest,[int(k)]])

# %% [markdown]
# Train and test data is initialized and updated using the following lines.

# %%
xTrain=np.zeros([len(aTrain),785])
xTrain[:,784]=np.full(len(aTrain),1)

xTest=np.zeros([len(aTest),785])
xTest[:,784]=np.full(len(aTest),1)

yactTrain=np.zeros([len(aTrain)])
ypredTrain=np.zeros([len(aTrain)])

yactTest=np.zeros([len(aTest)])
ypredTest=np.zeros([len(aTest)])

for i in range(len(aTrain)):
    xTrain[i,0:784]=imgarrayTrain[784*aTrain[i]:784*(aTrain[i]+1)]
    if labelsTrain[aTrain[i]]==0:
        yactTrain[i]=0
    else:
        yactTrain[i]=1
    ypredTrain[i]=1/(1+np.power(np.e,-np.dot(xTrain[i],weightsPred)))
 
for i in range(len(aTest)):
    xTest[i,0:784]=imgarrayTest[784*aTest[i]:784*(aTest[i]+1)]
    if labelsTest[aTest[i]]==0:
        yactTest[i]=0
    else:
        yactTest[i]=1

# %% [markdown]
# Gradient descent algorithm used to calculate the predicted weights array. Training data done here.

# %%
for i in range(100):
    for l in range(len(aTrain)):        
        gradient=np.dot((yactTrain[l]-ypredTrain[l]),xTrain[l,:])
        weightsPredPrev=weightsPred
        weightsPred=weightsPred+gradient*1E-5
        ypredTrain[l]=1/(1+np.power(np.e,-np.dot(xTrain[l],weightsPred)))
    iteration=iteration+1
# Out:
# C:\Users\srini\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: overflow encountered in power

# %% [markdown]
# Finally testing data used to check the accuracy of the model.

# %%
for i in range(len(aTest)):
    ypredTest[i]=1/(1+np.power(np.e,-np.dot(xTest[i],weightsPred)))
    cost-=(yactTest[i]*np.log10(ypredTest[i])+(1-yactTest[i])*np.log10(1-ypredTest[i]))
    if ypredTest[i]<0.5:
        ypredTest[i]=0
    else:
        ypredTest[i]=1
#print(slope)
print(cost)
print(np.mean(ypredTest==yactTest))
# Out:
# nan
# 0.999527186761
# C:\Users\srini\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log10
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\srini\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in double_scalars
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\srini\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in power

# %% [markdown]
# As observed, the accuracy of the model is 99.9527% on the testing data. Due to ypred values achieving almost 0 and 1 values, there usage in log function is leading to overflow and nan values.

# %%
for i in range(len(aTrain)):
    xTrain[i,0:784]=imgarrayTrain[784*aTrain[i]:784*(aTrain[i]+1)]/255
    if labelsTrain[aTrain[i]]==0:
        yactTrain[i]=0
    else:
        yactTrain[i]=1
    ypredTrain[i]=1/(1+np.power(np.e,-np.dot(xTrain[i],weightsPred)))
 
for i in range(len(aTest)):
    xTest[i,0:784]=imgarrayTest[784*aTest[i]:784*(aTest[i]+1)]/255
    if labelsTest[aTest[i]]==0:
        yactTest[i]=0
    else:
        yactTest[i]=1
# Out:
# C:\Users\srini\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: overflow encountered in power
#   import sys

# %%
import gzip
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

aTrain=np.zeros(1,dtype=int)
aTest=np.zeros(1,dtype=int)
countTrain=0;
countTest=0;
weightsPred=np.full(785,1)
weightsPredPrev=weightsPred*2

image1=np.zeros([28,28])
iteration=0       
cost=0

with gzip.open('C:\\Users\\srini\\OneDrive\\Academics\\ML courses\\ID 5030\\Assignments\\Assignment 2\\Digits\\train-images-idx3-ubyte.gz', 'rb') as f:
            imgarrayTrain = np.frombuffer(f.read(),dtype=np.uint8, offset=16)

with gzip.open('C:\\Users\\srini\\OneDrive\\Academics\\ML courses\\ID 5030\\Assignments\\Assignment 2\\Digits\\train-labels-idx1-ubyte.gz', 'rb') as f:
            labelsTrain = np.frombuffer(f.read(),dtype=np.uint8, offset=8)
            
with gzip.open('C:\\Users\\srini\\OneDrive\\Academics\\ML courses\\ID 5030\\Assignments\\Assignment 2\\Digits\\t10k-images-idx3-ubyte.gz', 'rb') as f:
            imgarrayTest = np.frombuffer(f.read(),dtype=np.uint8, offset=16)

with gzip.open('C:\\Users\\srini\\OneDrive\\Academics\\ML courses\\ID 5030\\Assignments\\Assignment 2\\Digits\\t10k-labels-idx1-ubyte.gz', 'rb') as f:
            labelsTest = np.frombuffer(f.read(),dtype=np.uint8, offset=8)
            
            
for k in range(len(labelsTrain)):
    if (labelsTrain[k]==1) | (labelsTrain[k]==0):
        countTrain=countTrain+1
        if countTrain==1:
            aTrain[0]=k
        else:
            aTrain=np.concatenate([aTrain,[int(k)]])

for k in range(len(labelsTest)):
    if (labelsTest[k]==1) | (labelsTest[k]==0):
        countTest=countTest+1
        if countTest==1:
            aTest[0]=k
        else:
            aTest=np.concatenate([aTest,[int(k)]])
            
xTrain=np.zeros([len(aTrain),785])
xTrain[:,784]=np.full(len(aTrain),1)

xTest=np.zeros([len(aTest),785])
xTest[:,784]=np.full(len(aTest),1)

yactTrain=np.zeros([len(aTrain)])
ypredTrain=np.zeros([len(aTrain)])

yactTest=np.zeros([len(aTest)])
ypredTest=np.zeros([len(aTest)])

for i in range(len(aTrain)):
    xTrain[i,0:784]=imgarrayTrain[784*aTrain[i]:784*(aTrain[i]+1)]/255
    if labelsTrain[aTrain[i]]==0:
        yactTrain[i]=0
    else:
        yactTrain[i]=1
    ypredTrain[i]=1/(1+np.power(np.e,-np.dot(xTrain[i],weightsPred)))
 
for i in range(len(aTest)):
    xTest[i,0:784]=imgarrayTest[784*aTest[i]:784*(aTest[i]+1)]/255
    if labelsTest[aTest[i]]==0:
        yactTest[i]=0
    else:
        yactTest[i]=1

for i in range(100):
    for l in range(len(aTrain)):
        gradient=np.dot((yactTrain[l]-ypredTrain[l]),xTrain[l,:])
        weightsPredPrev=weightsPred
        weightsPred=weightsPred+gradient*1E-5
        ypredTrain[l]=1/(1+np.power(np.e,-np.dot(xTrain[l],weightsPred)))
    iteration=iteration+1

for i in range(len(aTest)):
    ypredTest[i]=1/(1+np.power(np.e,-np.dot(xTest[i],weightsPred)))
    cost-=(yactTest[i]*np.log10(ypredTest[i])+(1-yactTest[i])*np.log10(1-ypredTest[i]))
    if ypredTest[i]<0.5:
        ypredTest[i]=0
    else:
        ypredTest[i]=1
print(cost)
print(np.mean(ypredTest==yactTest))
# Out:
# 66.7515586954
# 0.986761229314

# %% [markdown]
# Full program run with normalization of pixel values in the range (0,1). The accuracy is obtained as 98.67% which is slightly lesser than non normalized case.
#
# Normalization is helpful in cases where the features in wildly different units form an ellipsoid type of structure where gradient descent convergence would be difficult. In cases of image processing except in need of noise removal or contrast enhancement normalisation doesnt seem necessary. By avoiding normalization we are raising the exponent power to a very high value which leads to tighter alignment of values towards 1 or 0. Non normalization seems to work better in this case.
